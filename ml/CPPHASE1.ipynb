# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import math

# %%
df=pd.read_csv('round1.csv')

# %%
df.head()
print(df['Category'].unique())
print(df['Quota'].unique())
df['Quota'].replace(to_replace='AP',value='HS',inplace=True)
df['Quota'].replace(to_replace='GO',value='HS',inplace=True)
# Out:
# ['General' 'General PwD' 'EWS' 'OBC-NCL' 'OBC-NCL(PwD)' 'SC' 'SC PwD' 'ST'
#  'ST PwD' 'EWS PwD' 'GEN-EWS' 'OPEN' 'OPEN (PwD)' 'SC (PwD)'
#  'GEN-EWS(PwD)' 'ST (PwD)' 'OBC-\nNCL(PwD)' 'GEN-\nEWS(PwD)'
#  'OBC- NCL(PwD)' 'GEN- EWS(PwD)']
# ['AI' 'AP' 'GO' 'HS' 'OS']

# %%
df['Category'].replace(to_replace='General',value='GEN',inplace=True)
df['Category'].replace(to_replace='General PwD',value='GEN-PwD',inplace=True)
df['Category'].replace(to_replace='OBC-NCL(PwD)',value='OBC-NCL-PwD',inplace=True)
df['Category'].replace(to_replace='SC PwD',value='SC-PwD',inplace=True)
df['Category'].replace(to_replace='EWS PwD',value='EWS-PwD',inplace=True)
df['Category'].replace(to_replace='ST PwD',value='ST-PwD',inplace=True)
df['Category'].replace(to_replace='GEN-EWS',value='EWS',inplace=True)
df['Category'].replace(to_replace='SC (PwD)',value='SC-PwD',inplace=True)
df['Category'].replace(to_replace='SC PwD',value='SC-PwD',inplace=True)
df['Category'].replace(to_replace='GEN-EWS(PwD)',value='EWS-PwD',inplace=True)
df['Category'].replace(to_replace='ST (PwD)',value='ST-PwD',inplace=True)
df['Category'].replace(to_replace='OBC-\nNCL(PwD)',value='OBC-NCL-PwD',inplace=True)
df['Category'].replace(to_replace='GEN-\nEWS(PwD)',value='EWS-PwD',inplace=True)
df['Category'].replace(to_replace='OBC- NCL(PwD)',value='OBC-NCL-PwD',inplace=True)
df['Category'].replace(to_replace='GEN- EWS(PwD)',value='EWS-PwD',inplace=True)
df['Category'].replace(to_replace='OPEN (PwD)',value='OPEN-PwD',inplace=True)

# %%
df['Category'].unique()
# Out:
# array(['GEN', 'GEN-PwD', 'EWS', 'OBC-NCL', 'OBC-NCL-PwD', 'SC', 'SC-PwD',
#        'ST', 'ST-PwD', 'EWS-PwD', 'OPEN', 'OPEN-PwD'], dtype=object)

# %%
df.head
# Out:
# <bound method NDFrame.head of        Round\nNo                                          Institute  \
# 0              1  Atal Bihari Vajpayee Indian Institute of Infor...
# 1              1  Atal Bihari Vajpayee Indian Institute of Infor...
# 2              1  Atal Bihari Vajpayee Indian Institute of Infor...
# 3              1  Atal Bihari Vajpayee Indian Institute of Infor...
# 4              1  Atal Bihari Vajpayee Indian Institute of Infor...
# ...          ...                                                ...
# 42014          7  National Institute of Food Technology\nEntrepr...
# 42015          7  National Institute of Food Technology\nEntrepr...
# 42016          7  National Institute of Food Technology\nEntrepr...
# 42017          7  National Institute of Food Technology\nEntrepr...
# 42018          7  National Institute of Food Technology\nEntrepr...
#
#                                              Branch Name Quota     Category  \
# ...

# %%
df.rename(columns={'Round\nNo': 'Round No', 'Opening\nRank': 'Opening Rank'},inplace=True)

# %%
df.head()
# Out:
#    Round No                                          Institute  \
# 0         1  Atal Bihari Vajpayee Indian Institute of Infor...
# 1         1  Atal Bihari Vajpayee Indian Institute of Infor...
# 2         1  Atal Bihari Vajpayee Indian Institute of Infor...
# 3         1  Atal Bihari Vajpayee Indian Institute of Infor...
# 4         1  Atal Bihari Vajpayee Indian Institute of Infor...
#
#                                          Branch Name Quota     Category  \
# 0  Computer Science and Engineering(4 year, Bache...    AI          GEN
# 1  Computer Science and Engineering(4 year, Bache...    AI      GEN-PwD
# 2  Computer Science and Engineering(4 year, Bache...    AI          EWS
# 3  Computer Science and Engineering(4 year, Bache...    AI      OBC-NCL
# 4  Computer Science and Engineering(4 year, Bache...    AI  OBC-NCL-PwD
#
#         Seat Pool  Opening Rank  Closing Rank
# 0  Gender-Neutral        7536.0          9403
# 1  Gender-Neutral         264.0           264
# ...

# %%
df['Institute'].unique()
# Out:
# array(['Atal Bihari Vajpayee Indian Institute of Information Technology & Management Gwalior',
#        'Indian Institute of Information Technology (IIIT)Kota,\nRajasthan',
#        'Indian Institute of Information Technology Guwahati',
#        'Indian Institute of Information Technology(IIIT)\nKalyani, West Bengal',
#        'Indian Institute of Information Technology(IIIT)\nKilohrad, Sonepat, Haryana',
#        'Indian Institute of Information Technology(IIIT) Una,\nHimachal Pradesh',
#        'Indian Institute of Information Technology (IIIT), Sri\nCity, Chittoor',
#        'Indian Institute of Information Technology(IIIT),\nVadodara, Gujrat',
#        'Indian Institute of Information Technology, Allahabad',
#        'Indian Institute of Information Technology, Design &\nManufacturing, Kancheepuram',
#        'Indian Institute of Information Technology, Design & Manufacturing, Kancheepuram',
# ...

# %%
df.head()
df.shape
df.columns
# Out:
# Index(['Round No', 'Institute', 'Branch Name', 'Quota', 'Category',
#        'Seat Pool', 'Opening Rank', 'Closing Rank'],
#       dtype='object')

# %%
state=[]
df.Institute.unique()
# Out:
# array(['Atal Bihari Vajpayee Indian Institute of Information Technology & Management Gwalior',
#        'Indian Institute of Information Technology (IIIT)Kota,\nRajasthan',
#        'Indian Institute of Information Technology Guwahati',
#        'Indian Institute of Information Technology(IIIT)\nKalyani, West Bengal',
#        'Indian Institute of Information Technology(IIIT)\nKilohrad, Sonepat, Haryana',
#        'Indian Institute of Information Technology(IIIT) Una,\nHimachal Pradesh',
#        'Indian Institute of Information Technology (IIIT), Sri\nCity, Chittoor',
#        'Indian Institute of Information Technology(IIIT),\nVadodara, Gujrat',
#        'Indian Institute of Information Technology, Allahabad',
#        'Indian Institute of Information Technology, Design &\nManufacturing, Kancheepuram',
#        'Indian Institute of Information Technology, Design & Manufacturing, Kancheepuram',
# ...

# %%
df['Institute'].replace(to_replace='Ghani Khan Choudhary Institute of Engineering and\nTechnology, Malda, West Bengal',value='Ghani Khan Choudhary Institute of Engineering and Technology,Malda,West Bengal',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT)Kota,\nRajasthan',value='Indian Institute of Information Technology Kota,Rajasthan',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT)\nKalyani, West Bengal',value='Indian Institute of Information Technology Kalyani,West Bengal',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT)\nKilohrad, Sonepat, Haryana',value='Indian Institute of Information Technology Sonepat,Haryana',inplace=True)

def set_value(row_number, assigned_value): 
    return assigned_value[row_number] 
state={'Assam University, Silchar' : 'Assam', 'National Institute of Technology, Tiruchirappalli' : 'Tamil Nadu', 
       'Sardar Vallabhbhai National Institute of Technology Surat' : 'Gujarat','Atal Bihari Vajpayee Indian Institute of Information Technology & Management Gwalior':'All India',
      'Indian Institute of Information Technology Kota,Rajasthan':'All India',
       'Indian Institute of Information Technology Guwahati':'All India',
       'Indian Institute of Information Technology Kalyani,West Bengal':'All India',
       'Indian Institute of Information Technology Sonepat,Haryana':'All India',
       'Indian Institute of Information Technology Una,Himachal Pradesh':'All India',
       'Indian Institute of Information Technology Sri City,Chittoor':'All India',
       'Indian Institute of Information Technology Vadodara,Gujarat':'All India',
       'Indian Institute of Information Technology Allahabad':'All India',
       'Indian Institute of Information Technology Design & Manufacturing,Kancheepuram':'All India',
       'Pt. Dwarka Prasad Mishra Indian Institute of Information Technology Design & Manufacture Jabalpur':'All India',
       'Indian Institute of Information Technology Manipur':'All India',
       'Indian Institute of Information Technology Tiruchirappalli':'All India',
       'Indian Institute of Information Technology Lucknow':'All India',
       'Indian Institute of Information Technology Dharwad':'All India',
       'Indian Institute of Information Technology Design & Manufacturing Kurnool,Andhra Pradesh':'All India',
       'Indian Institute of Information Technology Kottayam':'All India',
       'Indian Institute of Information Technology Ranchi':'All India',
       'Indian Institute of Information Technology Nagpur':'All India',
       'Indian Institute of Information Technology Pune':'All India',
       'Indian Institute of Information Technology Bhagalpur':'All India',
       'Indian Institute of Information Technology Bhopal':'All India',
       'Indian Institute of Information Technology Surat':'All India',
       'Indian Institute of Information Technology Agartala':'All India',
       'Indian institute of information Technology,Raichur,Karnataka':'All India','Gurukula Kangri Vishwavidyalaya, Haridwar':'All India',
      'Institute of Technology, Guru Ghasidas Vishwavidyalaya,Bilaspur,(C.G.)':'All India',
       'J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication, University of Allahabad':'All India',
      'Indian Institute of Carpet Technology,  Bhadohi':'All India','National Institute of Electronics and Information Technology, Aurangabad,Maharashtra':'All India',
      'National Institute of Foundry & Forge Technology,Hatia,Ranchi':'All India',
       'Sant Longowal Institute of Engineering and Technology':'All India',
       'Mizoram University, Aizawl':'All India',
       'School of Engineering,Tezpur University,Napaam,Tezpur':'All India',
       'School of Planning & Architecture, Bhopal':'All India',
       'School of Planning & Architecture, New Delhi':'All India',
       'School of Planning & Architecture,Vijayawada':'All India',
       'Shri Mata Vaishno Devi University,Katra,Jammu & Kashmir':'All India',
       'HNB Garhwal University Srinagar Garhwal':'All India',
       'International Institute of Information Technology,Naya Raipur':'All India',
       'University of Hyderabad':'All India', 'Jawaharlal Nehru University, Delhi':'All India',
       'International Institute of Information Technology,Bhubaneswar':'All India',
       'Central institute of Technology Kokrajar, Assam':'All India',
       'Pondicherry Engineering College, Puducherry':'All India',
       'Central University of Rajasthan, Rajasthan':'All India',
       'National Institute of Food Technology Entrepreneurship and Management,Sonepat,Haryana':'All India',
      'National Institute of Technology, Warangal':'Andhra Pradesh',
       'National Institute of Technology Goa':'Goa','Dr. B R Ambedkar National Institute of Technology,Jalandhar':'Punjab',
       'Malaviya National Institute of Technology Jaipur':'Rajashtahn',
       'Maulana Azad National Institute of Technology Bhopal':'Madhya Pradesh',
       'Motilal Nehru National Institute of Technology Allahabad':'Uttar Pradesh',
       'National Institute of Technology  Agartala':'Tripura',
       'National Institute of Technology Calicut':'Kerela',
       'National Institute of Technology Delhi':'Delhi',
       'National Institute of Technology Durgapur':'West Bengal',
       'National Institute of Technology Hamirpur':'Himachal Pradesh',
       'National Institute of Technology Surathkal,Karnataka':'Karnataka',
       'National Institute of Technology Meghalaya':'Meghalaya',
       'National Institute of Technology Nagaland':'Nagaland',
       'National Institute of Technology Patna':'Bihar',
       'National Institute of Technology Puducherry':'Puducherry',
       'National Institute of Technology Raipur':'Chattisgarh',
       'National Institute of Technology Sikkim':'Sikkim',
       'National Institute of Technology Arunachal Pradesh':'Arunachal Pradesh',
       'National Institute of Technology, Jamshedpur':'Jharkhand',
       'National Institute of Technology, Kurukshetra':'Haryana',
       'National Institute of Technology, Manipur':'Manipur',
       'National Institute of Technology, Mizoram':'Mizoram',
       'National Institute of Technology, Rourkela':'Odhisa',
       'National Institute of Technology, Silchar':'Assam',
       'National Institute of Technology, Srinagar':'Jammu & Kahmir',
       'National Institute of Technology, Tiruchirappalli':'Tamil Nadu',
       'National Institute of Technology, Uttarakhand':'Uttarakhand',
       'Sardar Vallabhbhai National Institute of Technology Surat':'Gujarat',
       'Visvesvaraya National Institute of Technology Nagpur':'Maharashtra',
       'National Institute of Technology, Andhra Pradesh':'Andhra Pradesh',
       'Birla Institute of Technology, Mesra,Ranchi':'Jharkhand',
       'Indian Institute of Engineering Science and Technology, Shibpur':'West Bengal',
       'Punjab Engineering College, Chandigarh':'Punjab',
       'Ghani Khan Choudhary Institute of Engineering and Technology,Malda,West Bengal':'West Bengal',
       'Institute of Infrastructure Technology Research and Management,Ahmedabad':'All India',
       'Indian Institute  of Technology Bhubaneswar':'qwer'
      } 
df['State'] = df['Institute'].apply(set_value, args =(state, ))
df.head(50)
# Out:
#     Round No                                          Institute  \
# 0          1  Atal Bihari Vajpayee Indian Institute of Infor...
# 1          1  Atal Bihari Vajpayee Indian Institute of Infor...
# 2          1  Atal Bihari Vajpayee Indian Institute of Infor...
# 3          1  Atal Bihari Vajpayee Indian Institute of Infor...
# 4          1  Atal Bihari Vajpayee Indian Institute of Infor...
# 5          1  Atal Bihari Vajpayee Indian Institute of Infor...
# 6          1  Atal Bihari Vajpayee Indian Institute of Infor...
# 7          1  Atal Bihari Vajpayee Indian Institute of Infor...
# 8          1  Atal Bihari Vajpayee Indian Institute of Infor...
# 9          1  Atal Bihari Vajpayee Indian Institute of Infor...
# 10         1  Atal Bihari Vajpayee Indian Institute of Infor...
# 11         1  Atal Bihari Vajpayee Indian Institute of Infor...
# 12         1  Atal Bihari Vajpayee Indian Institute of Infor...
# 13         1  Atal Bihari Vajpayee Indian Institute of Infor...
# ...

# %%
df['Institute'].replace(to_replace='Maulana Azad National Institute of Technology\nBhopal',value='Maulana Azad National Institute of Technology Bhopal',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT) Una,\nHimachal Pradesh',value='Indian Institute of Information Technology Una,Himachal Pradesh',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT), Sri\nCity, Chittoor',value='Indian Institute of Information Technology Sri City,Chittoor',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT),\nVadodara, Gujrat',value='Indian Institute of Information Technology Vadodara,Gujarat',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology, Allahabad',value='Indian Institute of Information Technology Allahabad',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology, Design &\nManufacturing, Kancheepuram',value='Indian Institute of Information Technology Design & Manufacturing,Kancheepuram',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology, Design & Manufacturing, Kancheepuram',value='Indian Institute of Information Technology Design & Manufacturing,Kancheepuram',inplace=True)
df['Institute'].replace(to_replace='Pt. Dwarka Prasad Mishra Indian Institute of Information Technology, Design & Manufacture\nJabalpur',value='Pt. Dwarka Prasad Mishra Indian Institute of Information Technology Design & Manufacture Jabalpur',inplace=True)
df['Institute'].replace(to_replace='Pt. Dwarka Prasad Mishra Indian Institute of\nInformation Technology, Design & Manufacture Jabalpur',value='Pt. Dwarka Prasad Mishra Indian Institute of Information Technology Design & Manufacture Jabalpur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology  Manipur',value='Indian Institute of Information Technology Manipur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology Srirangam,\nTiruchirappalli',value='Indian Institute of Information Technology Tiruchirappalli',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT)\nDharwad',value='Indian Institute of Information Technology Dharwad',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology Design & Manufacturing Kurnool, Andhra Pradesh',value='Indian Institute of Information Technology Design & Manufacturing Kurnool,Andhra Pradesh',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT)\nKottayam',value='Indian Institute of Information Technology Kottayam',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT) Ranchi',value='Indian Institute of Information Technology Ranchi',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT)\nNagpur',value='Indian Institute of Information Technology Nagpur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT) Pune',value='Indian Institute of Information Technology Pune',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology, Agartala',value='Indian Institute of Information Technology Agartala',inplace=True)
df['Institute'].replace(to_replace='Indian institute of information technology, Raichur,\nKarnataka',value='Indian institute of information Technology,Raichur,Karnataka',inplace=True)
df['Institute'].replace(to_replace='Institute of Infrastructure, Technology, Research and\nManagement-Ahmedabad',value='Institute of Infrastructure Technology Research and Management,Ahmedabad',inplace=True)
df['Institute'].replace(to_replace='Institute of Technology, Guru Ghasidas Vishwavidyalaya (A Central University), Bilaspur, (C.G.)',value='Institute of Technology, Guru Ghasidas Vishwavidyalaya,Bilaspur,(C.G.)',inplace=True)
df['Institute'].replace(to_replace='J.K. Institute of Applied Physics & Technology, Department of Electronics & Communication, University of Allahabad- Allahabad',value='J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication, University of Allahabad',inplace=True)
df['Institute'].replace(to_replace='National Institute of Electronics and Information Technology, Aurangabad (Maharashtra)',value='National Institute of Electronics and Information Technology, Aurangabad,Maharashtra',inplace=True)
df['Institute'].replace(to_replace='National Institute of Foundry & Forge Technology,\nHatia, Ranchi',value='National Institute of Foundry & Forge Technology,Hatia,Ranchi',inplace=True)
df['Institute'].replace(to_replace='Sant Longowal Institute of Engineering and\nTechnology',value='Sant Longowal Institute of Engineering and Technology',inplace=True)
df['Institute'].replace(to_replace='School of Engineering, Tezpur University, Napaam,\nTezpur',value='School of Engineering,Tezpur University,Napaam,Tezpur',inplace=True)
df['Institute'].replace(to_replace='School of Planning & Architecture: Vijayawada',value='School of Planning & Architecture,Vijayawada',inplace=True)
df['Institute'].replace(to_replace='Shri Mata Vaishno Devi University, Katra, Jammu &\nKashmir',value='Shri Mata Vaishno Devi University,Katra,Jammu & Kashmir',inplace=True)
df['Institute'].replace(to_replace='HNB Garhwal University Srinagar (Garhwal)',value='HNB Garhwal University Srinagar Garhwal',inplace=True)
df['Institute'].replace(to_replace='International Institute of Information Technology,\nNaya Raipur',value='International Institute of Information Technology,Naya Raipur',inplace=True)
df['Institute'].replace(to_replace='International Institute of Information Technology,\nBhubaneswar',value='International Institute of Information Technology,Bhubaneswar',inplace=True)
df['Institute'].replace(to_replace='National Institute of Food Technology\nEntrepreneurship and Management, Sonepat, Haryana',value='National Institute of Food Technology Entrepreneurship and Management,Sonepat,Haryana',inplace=True)
df['Institute'].replace(to_replace='National Institute of Food Technology Entrepreneurship and Management, Sonepat,\nHaryana',value='National Institute of Food Technology Entrepreneurship and Management,Sonepat,Haryana',inplace=True)

# %%
df['Institute'].replace(to_replace='Dr. B R Ambedkar National Institute of Technology,\nJalandhar',value='Dr. B R Ambedkar National Institute of Technology,Jalandhar',inplace=True)
df['Institute'].replace(to_replace='Motilal Nehru National Institute of Technology\nAllahabad',value='Motilal Nehru National Institute of Technology Allahabad',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology Karnataka, Surathkal',value='National Institute of Technology Surathkal,Karnataka',inplace=True)
df['Institute'].replace(to_replace='Sardar Vallabhbhai National Institute of Technology,\nSurat',value='Sardar Vallabhbhai National Institute of Technology Surat',inplace=True)
df['Institute'].replace(to_replace='Birla Institute of Technology, Mesra,  Ranchi',value='Birla Institute of Technology, Mesra,Ranchi',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Engineering Science and\nTechnology, Shibpur',value='Indian Institute of Engineering Science and Technology, Shibpur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT) Kalyani,\nWest Bengal',value='Indian Institute of Information Technology Kalyani,West Bengal',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT) Kilohrad,\nSonepat, Haryana',value='Indian Institute of Information Technology Sonepat,Haryana',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT), Sri City,\nChittoor',value='Indian Institute of Information Technology Sri City,Chittoor',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT), Vadodara,\nGujrat',value='Indian Institute of Information Technology Vadodara,Gujarat',inplace=True)
df['Institute'].replace(to_replace='Pt. Dwarka Prasad Mishra Indian Institute of Information Technology, Design & Manufacture Jabalpur',value='Pt. Dwarka Prasad Mishra Indian Institute of Information Technology Design & Manufacture Jabalpur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT) Dharwad',value='Indian Institute of Information Technology Dharwad',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT) Kottayam',value='Indian Institute of Information Technology Kottayam',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT) Nagpur',value='Indian Institute of Information Technology Nagpur',inplace=True)
df['Institute'].replace(to_replace='J.K. Institute of Applied Physics & Technology, Department of Electronics & Communication, University of Allahabad-\nAllahabad',value='J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication, University of Allahabad',inplace=True)
df['Institute'].replace(to_replace='J.K. Institute of Applied Physics & Technology, Department\nof Electronics & Communication, University of Allahabad- Allahabad',value='J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication, University of Allahabad',inplace=True)
df['Institute'].replace(to_replace='National Institute of Foundry & Forge Technology, Hatia,\nRanchi',value='National Institute of Foundry & Forge Technology,Hatia,Ranchi',inplace=True)
df['Institute'].replace(to_replace='School of Engineering, Tezpur University, Napaam, Tezpur',value='School of Engineering,Tezpur University,Napaam,Tezpur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Engineering Science and Technology,\nShibpur',value='Indian Institute of Engineering Science and Technology, Shibpur',inplace=True)
df['Institute'].replace(to_replace='International Institute of Information Technology, Naya\nRaipur',value='International Institute of Information Technology,Naya Raipur',inplace=True)
df['Institute'].replace(to_replace='J.K. Institute of Applied Physics & Technology,\nDepartment of Electronics & Communication, University of Allahabad- Allahabad',value='J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication, University of Allahabad',inplace=True)
df['Institute'].replace(to_replace='J.K. Institute of Applied Physics & Technology, Department of Electronics & Communication,\nUniversity of Allahabad- Allahabad',value='J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication, University of Allahabad',inplace=True)
df['Institute'].replace(to_replace='Institute of Technology, Guru Ghasidas\nVishwavidyalaya (A Central University), Bilaspur, (C.G.)',value='Institute of Technology, Guru Ghasidas Vishwavidyalaya,Bilaspur,(C.G.)',inplace=True)
df['Institute'].replace(to_replace='Visvesvaraya National Institute of Technology,\nNagpur',value='Visvesvaraya National Institute of Technology Nagpur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT)\nRanchi',value='Indian Institute of Information Technology Ranchi',inplace=True)
df['Institute'].replace(to_replace='Pt. Dwarka Prasad Mishra Indian Institute of\nInformation Technology, Design & Manufacture\nJabalpur',value='Pt. Dwarka Prasad Mishra Indian Institute of Information Technology Design & Manufacture Jabalpur',inplace=True)
df['Institute'].replace(to_replace='National Institute of Food Technology Entrepreneurship and Management, Sonepat, Haryana',value='National Institute of Food Technology Entrepreneurship and Management,Sonepat,Haryana',inplace=True)
df['Institute'].replace(to_replace='Ghani Khan Choudhary Institute of Engineering and Technology, Malda, West Bengal',value='Ghani Khan Choudhary Institute of Engineering and Technology,Malda,West Bengal',inplace=True)

# %%
df['Institute'].replace(to_replace='Visvesvaraya National Institute of Technology, Nagpur',value='Visvesvaraya National Institute of Technology Nagpur',inplace=True)
df['Institute'].replace(to_replace='Ghani Khan Choudhary Institute of Engineering and Technology, Malda, West Bengal',value='Ghani Khan Choudhary Institute of Engineering and Technology,Malda,West Bengal',inplace=True)
df['Institute'].replace(to_replace='Sardar Vallabhbhai National Institute of Technology, Surat',value='Sardar Vallabhbhai National Institute of Technology Surat',inplace=True)

# %%
df.tail()
print(df.dtypes)
df['Closing Rank']=df['Closing Rank'].astype(int)
# Out:
# Round No          int64
# Institute        object
# Branch Name      object
# Quota            object
# Category         object
# Seat Pool        object
# Opening Rank    float64
# Closing Rank      int64
# dtype: object

# %%
def final2(rank,category,state,gender,pwd):
    if(pwd=='YES'):
        if(gender=='M'):
            catg=category+'-PwD'
            p=df[(df['Closing Rank']>=rank)&((df['Category']==catg)|(df['Category']=='OPEN-PwD'))&(df['Seat Pool']=='Gender-Neutral')]
        else:
            catg=category+'-PwD'
            p=df[(df['Closing Rank']>=rank)&((df['Category']==catg)|(df['Category']=='OPEN-PwD'))]
    else:
        if(gender=='M'):
            p=df[(df['Closing Rank']>=rank)&((df['Category']==category)|(df['Category']=='OPEN'))&(df['Seat Pool']=='Gender-Neutral')]
        else:
             p=df[(df['Closing Rank']>=rank)&((df['Category']==category)|(df['Category']=='OPEN'))]  
    return p

# %%
df2=final2(1311,'GEN','Andhra Pradesh','M','NO')
s='Andhra Pradesh'
k=[]
for i in df2.index:
    if(df2['State'][i]==s):
        if(df2['Quota'][i]=='OS'):
            k.append(i)
    elif((df2['State'][i]!='All India')&(df2['State'][i]!=s)):
        if(df2['Quota'][i]=='HS'):
            k.append(i)
q=df2.drop(index=k)
q
# Out:
#        Round No                                          Institute  \
# 0             1  Atal Bihari Vajpayee Indian Institute of Infor...
# 12            1  Atal Bihari Vajpayee Indian Institute of Infor...
# 24            1  Atal Bihari Vajpayee Indian Institute of Infor...
# 35            1  Indian Institute of Information Technology Kot...
# 44            1  Indian Institute of Information Technology Kot...
# ...         ...                                                ...
# 41992         7  Ghani Khan Choudhary Institute of Engineering ...
# 42000         7  Ghani Khan Choudhary Institute of Engineering ...
# 42005         7         Central University of Rajasthan, Rajasthan
# 42010         7         Central University of Rajasthan, Rajasthan
# 42015         7  National Institute of Food Technology Entrepre...
#
#                                              Branch Name Quota Category  \
# 0      Computer Science and Engineering(4 year, Bache...    AI      GEN
# ...

# %%
rvp=pd.read_csv('rankVperc.csv')
rvp.head()
# Out:
#   CATEGORY  RANK  PERCENTILE
# 0  GENERAL    13     100.000
# 1  GENERAL    34      99.999
# 2  GENERAL    53      99.998
# 3  GENERAL    69      99.997
# 4  GENERAL    80      99.996

# %%
rvp.head()
rvp['RANK']=rvp['RANK'].astype(int)
rvp.dtypes
# Out:
# CATEGORY       object
# RANK            int32
# PERCENTILE    float64
# dtype: object

# %%
rvp['CATEGORY'].unique()
rvp['CATEGORY'].replace(to_replace='OBC',value='OBC-NCL',inplace=True)
rvp['CATEGORY'].replace(to_replace='OBC-PWD',value='OBC-NCL-PwD',inplace=True)
rvp['CATEGORY'].replace(to_replace='GENERAL',value='GEN',inplace=True)
rvp['CATEGORY'].replace(to_replace='GENERAL-PWD',value='GEN-PwD',inplace=True)
rvp['CATEGORY'].replace(to_replace='SC-PWD',value='SC-PwD',inplace=True)
rvp['CATEGORY'].replace(to_replace='ST-PWD',value='ST-PwD',inplace=True)
rvp['CATEGORY'].unique()
# Out:
# array(['GEN', 'EWS', 'OBC-NCL', 'SC', 'ST', 'GEN-PwD', 'EWS-PWD',
#        'OBC-NCL-PwD', 'SC-PwD', 'ST-PwD'], dtype=object)

# %%
rvp_g=rvp[rvp['CATEGORY']=='GEN']
rvp_gp=rvp[rvp['CATEGORY']=='GEN-PwD']
rvp_e=rvp[rvp['CATEGORY']=='EWS']
rvp_ep=rvp[rvp['CATEGORY']=='EWS-PwD']
rvp_sc=rvp[rvp['CATEGORY']=='SC']
rvp_scp=rvp[rvp['CATEGORY']=='SC-PwD']
rvp_st=rvp[rvp['CATEGORY']=='ST']
rvp_stp=rvp[rvp['CATEGORY']=='ST-PwD']
rvp_ob=rvp[rvp['CATEGORY']=='OBC-NCL']
rvp_obp=rvp[rvp['CATEGORY']=='OBC-NCL-PwD']

# %%
X=rvp_g['PERCENTILE'].values.reshape(-1,1)
y=rvp_g['RANK'].values.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)
x=pd.Series([98.9])
regressor.predict(x.values.reshape(-1,1))
# Out:
# array([[12961.92824104]])

# %%
def phrdo(perc,pwd,category):
    if(pwd=='YES'):
        if(category=='GEN'):
            X=rvp_gp['PERCENTILE'].values.reshape(-1,1)
            y=rvp_gp['RANK'].values.reshape(-1,1)
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
            regressor = LinearRegression()  
            regressor.fit(X_train, y_train) 
            x=pd.Series([perc])
            z=regressor.predict(x.values.reshape(-1,1))
        elif(category=='SC'):
            X=rvp_scp['PERCENTILE'].values.reshape(-1,1)
            y=rvp_scp['RANK'].values.reshape(-1,1)
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
            regressor = LinearRegression()  
            regressor.fit(X_train, y_train) 
            x=pd.Series([perc])
            z=regressor.predict(x.values.reshape(-1,1))
        elif(category=='ST'):
            X=rvp_stp['PERCENTILE'].values.reshape(-1,1)
            y=rvp_stp['RANK'].values.reshape(-1,1)
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
            regressor = LinearRegression()  
            regressor.fit(X_train, y_train) 
            x=pd.Series([perc])
            z=regressor.predict(x.values.reshape(-1,1))
        elif(category=='EWS'):
            X=rvp_ep['PERCENTILE'].values.reshape(-1,1)
            y=rvp_ep['RANK'].values.reshape(-1,1)
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
            regressor = LinearRegression()  
            regressor.fit(X_train, y_train) 
            x=pd.Series([perc])
            z=regressor.predict(x.values.reshape(-1,1))
        else:
            X=rvp_obp['PERCENTILE'].values.reshape(-1,1)
            y=rvp_obp['RANK'].values.reshape(-1,1)
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
            regressor = LinearRegression()  
            regressor.fit(X_train, y_train) 
            x=pd.Series([perc])
            z=regressor.predict(x.values.reshape(-1,1))
    else:
        if(category=='GEN'):
            X=rvp_g['PERCENTILE'].values.reshape(-1,1)
            y=rvp_g['RANK'].values.reshape(-1,1)
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
            regressor = LinearRegression()  
            regressor.fit(X_train, y_train) 
            x=pd.Series([perc])
            z=regressor.predict(x.values.reshape(-1,1))
        elif(category=='SC'):
            X=rvp_sc['PERCENTILE'].values.reshape(-1,1)
            y=rvp_sc['RANK'].values.reshape(-1,1)
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
            regressor = LinearRegression()  
            regressor.fit(X_train, y_train) 
            x=pd.Series([perc])
            z=regressor.predict(x.values.reshape(-1,1))
        elif(category=='ST'):
            X=rvp_st['PERCENTILE'].values.reshape(-1,1)
            y=rvp_st['RANK'].values.reshape(-1,1)
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
            regressor = LinearRegression()  
            regressor.fit(X_train, y_train) 
            x=pd.Series([perc])
            z=regressor.predict(x.values.reshape(-1,1))
        elif(category=='EWS'):
            X=rvp_e['PERCENTILE'].values.reshape(-1,1)
            y=rvp_e['RANK'].values.reshape(-1,1)
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
            regressor = LinearRegression()  
            regressor.fit(X_train, y_train) 
            x=pd.Series([perc])
            z=regressor.predict(x.values.reshape(-1,1))
        else:
            X=rvp_ob['PERCENTILE'].values.reshape(-1,1)
            y=rvp_ob['RANK'].values.reshape(-1,1)
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
            regressor = LinearRegression()  
            regressor.fit(X_train, y_train) 
            x=pd.Series([perc])
            z=regressor.predict(x.values.reshape(-1,1))
    return z

# %%
phrdo(95,'NO','GEN')
# Out:
# array([[59228.33135931]])
