# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import math

# %%
df=pd.read_csv('round1.csv')

# %%
df.head()
print(df['Category'].unique())
print(df['Quota'].unique())
df['Quota'].replace(to_replace='AP',value='HS',inplace=True)
df['Quota'].replace(to_replace='GO',value='HS',inplace=True)
# Out:
# ['General' 'General PwD' 'EWS' 'OBC-NCL' 'OBC-NCL(PwD)' 'SC' 'SC PwD' 'ST'
#  'ST PwD' 'EWS PwD' 'GEN-EWS' 'OPEN' 'OPEN (PwD)' 'SC (PwD)'
#  'GEN-EWS(PwD)' 'ST (PwD)' 'OBC-\r\nNCL(PwD)' 'GEN-\r\nEWS(PwD)'
#  'OBC- NCL(PwD)' 'GEN- EWS(PwD)']
# ['AI' 'AP' 'GO' 'HS' 'OS']

# %%
df['Category'].replace(to_replace='General',value='GEN',inplace=True)
df['Category'].replace(to_replace='General PwD',value='GEN-PwD',inplace=True)
df['Category'].replace(to_replace='OBC-NCL(PwD)',value='OBC-NCL-PwD',inplace=True)
df['Category'].replace(to_replace='SC PwD',value='SC-PwD',inplace=True)
df['Category'].replace(to_replace='EWS PwD',value='EWS-PwD',inplace=True)
df['Category'].replace(to_replace='ST PwD',value='ST-PwD',inplace=True)
df['Category'].replace(to_replace='GEN-EWS',value='EWS',inplace=True)
df['Category'].replace(to_replace='SC (PwD)',value='SC-PwD',inplace=True)
df['Category'].replace(to_replace='SC PwD',value='SC-PwD',inplace=True)
df['Category'].replace(to_replace='GEN-EWS(PwD)',value='EWS-PwD',inplace=True)
df['Category'].replace(to_replace='ST (PwD)',value='ST-PwD',inplace=True)
df['Category'].replace(to_replace='OBC-\nNCL(PwD)',value='OBC-NCL-PwD',inplace=True)
df['Category'].replace(to_replace='GEN-\nEWS(PwD)',value='EWS-PwD',inplace=True)
df['Category'].replace(to_replace='OBC- NCL(PwD)',value='OBC-NCL-PwD',inplace=True)
df['Category'].replace(to_replace='GEN- EWS(PwD)',value='EWS-PwD',inplace=True)
df['Category'].replace(to_replace='OPEN (PwD)',value='OPEN-PwD',inplace=True)

# %%
df['Category'].unique()
# Out:
# array(['GEN', 'GEN-PwD', 'EWS', 'OBC-NCL', 'OBC-NCL-PwD', 'SC', 'SC-PwD',
#        'ST', 'ST-PwD', 'EWS-PwD', 'OPEN', 'OPEN-PwD', 'OBC-\r\nNCL(PwD)',
#        'GEN-\r\nEWS(PwD)'], dtype=object)

# %%
df.head()
# Out:
#                                            Institute  \
# 0  Atal Bihari Vajpayee Indian Institute of Infor...
# 1  Atal Bihari Vajpayee Indian Institute of Infor...
# 2  Atal Bihari Vajpayee Indian Institute of Infor...
# 3  Atal Bihari Vajpayee Indian Institute of Infor...
# 4  Atal Bihari Vajpayee Indian Institute of Infor...
#
#                                          Branch Name Quota     Category  \
# 0  Computer Science and Engineering(4 year, Bache...    AI          GEN
# 1  Computer Science and Engineering(4 year, Bache...    AI      GEN-PwD
# 2  Computer Science and Engineering(4 year, Bache...    AI          EWS
# 3  Computer Science and Engineering(4 year, Bache...    AI      OBC-NCL
# 4  Computer Science and Engineering(4 year, Bache...    AI  OBC-NCL-PwD
#
#         Seat Pool  Opening Rank  Closing Rank  Round\r\nNo
# 0  Gender-Neutral        7536.0          9403            1
# 1  Gender-Neutral         264.0           264            1
# ...

# %%
df.rename(columns={'Round\nNo': 'Round No', 'Opening\nRank': 'Opening Rank','Round\r\nNo':'Round No'},inplace=True)

# %%
df.head()
# Out:
#                                            Institute  \
# 0  Atal Bihari Vajpayee Indian Institute of Infor...
# 1  Atal Bihari Vajpayee Indian Institute of Infor...
# 2  Atal Bihari Vajpayee Indian Institute of Infor...
# 3  Atal Bihari Vajpayee Indian Institute of Infor...
# 4  Atal Bihari Vajpayee Indian Institute of Infor...
#
#                                          Branch Name Quota     Category  \
# 0  Computer Science and Engineering(4 year, Bache...    AI          GEN
# 1  Computer Science and Engineering(4 year, Bache...    AI      GEN-PwD
# 2  Computer Science and Engineering(4 year, Bache...    AI          EWS
# 3  Computer Science and Engineering(4 year, Bache...    AI      OBC-NCL
# 4  Computer Science and Engineering(4 year, Bache...    AI  OBC-NCL-PwD
#
#         Seat Pool  Opening Rank  Closing Rank  Round No
# 0  Gender-Neutral        7536.0          9403         1
# 1  Gender-Neutral         264.0           264         1
# ...

# %%
print(df['Institute'].unique())
len(df['Institute'].unique())
# Out:
# ['IIIT-M Gwalior' 'IIIT Kota' 'IIIT Guwahati' 'IIIT Kalyani'
#  'IIIT Sonepat' 'IIIT Una' 'IIIT Sri City' 'IIIT Vadodara'
#  'IIIT Allahabad' 'IIIT-DM Kancheepuram' 'IIIT-DM Jabalpur' 'IIIT Manipur'
#  'IIIT Tiruchirappalli' 'IIIT Lucknow' 'IIIT Dharwad' 'IIIT-DM Kurnool'
#  'IIIT Kottayam' 'IIIT Ranchi' 'IIIT Nagpur' 'IIIT Pune' 'IIIT Bhagalpur'
#  'IIIT Bhopal' 'IIIT Surat' 'IIIT Agartala' 'IIIT Raichur'
#  'Assam University, Silchar' 'Gurukula Kangri Vishwavidyalaya, Haridwar'
#  'Indian Institute of Carpet Technology,  Bhadohi'
#  'Institute of Infrastructure Technology Research and Management,Ahmedabad'
#  'Institute of Technology,Guru Ghasidas Vishwavidyalaya,Bilaspur,(C.G.)'
#  'J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication,University of Allahabad'
#  'National Institute of Electronics and Information Technology, Aurangabad,Maharashtra'
#  'National Institute of Foundry & Forge Technology,Ranchi'
# ...

# %%
df['Institute'].replace(to_replace='Maulana Azad National Institute of Technology\nBhopal',value='NIT Bhopal',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT) Una,\nHimachal Pradesh',value='IIIT Una',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT), Sri\nCity, Chittoor',value='IIIT Sri City',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT),\nVadodara, Gujrat',value='IIIT Vadodara',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology, Allahabad',value='IIIT Allahabad',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology, Design &\nManufacturing, Kancheepuram',value='IIIT-DM Kancheepuram',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology, Design & Manufacturing, Kancheepuram',value='IIIT-DM Kancheepuram',inplace=True)
df['Institute'].replace(to_replace='Pt. Dwarka Prasad Mishra Indian Institute of Information Technology, Design & Manufacture\nJabalpur',value='IIIT-DM Jabalpur',inplace=True)
df['Institute'].replace(to_replace='Pt. Dwarka Prasad Mishra Indian Institute of\nInformation Technology, Design & Manufacture Jabalpur',value='IIIT-DM Jabalpur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology  Manipur',value='IIIT Manipur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology Srirangam,\nTiruchirappalli',value='IIIT Tiruchirappalli',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT)\nDharwad',value='IIIT Dharwad',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology Design & Manufacturing Kurnool, Andhra Pradesh',value='IIIT-DM Kurnool',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT)\nKottayam',value='IIIT Kottayam',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT) Ranchi',value='IIIT Ranchi',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT)\nNagpur',value='IIIT Nagpur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT) Pune',value='IIIT Pune',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology, Agartala',value='IIIT Agartala',inplace=True)
df['Institute'].replace(to_replace='Indian institute of information technology, Raichur,\nKarnataka',value='IIIT Raichur',inplace=True)
df['Institute'].replace(to_replace='Institute of Infrastructure, Technology, Research and\nManagement-Ahmedabad',value='Institute of Infrastructure Technology Research and Management,Ahmedabad',inplace=True)
df['Institute'].replace(to_replace='Institute of Technology, Guru Ghasidas Vishwavidyalaya (A Central University), Bilaspur, (C.G.)',value='Institute of Technology, Guru Ghasidas Vishwavidyalaya,Bilaspur,(C.G.)',inplace=True)
df['Institute'].replace(to_replace='J.K. Institute of Applied Physics & Technology, Department of Electronics & Communication, University of Allahabad- Allahabad',value='J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication, University of Allahabad',inplace=True)
df['Institute'].replace(to_replace='National Institute of Electronics and Information Technology, Aurangabad (Maharashtra)',value='National Institute of Electronics and Information Technology, Aurangabad,Maharashtra',inplace=True)
df['Institute'].replace(to_replace='National Institute of Foundry & Forge Technology,\nHatia, Ranchi',value='National Institute of Foundry & Forge Technology,Hatia,Ranchi',inplace=True)
df['Institute'].replace(to_replace='Sant Longowal Institute of Engineering and\nTechnology',value='Sant Longowal Institute of Engineering and Technology',inplace=True)
df['Institute'].replace(to_replace='School of Engineering, Tezpur University, Napaam,\nTezpur',value='School of Engineering,Tezpur University,Napaam,Tezpur',inplace=True)
df['Institute'].replace(to_replace='School of Planning & Architecture: Vijayawada',value='School of Planning & Architecture,Vijayawada',inplace=True)
df['Institute'].replace(to_replace='Shri Mata Vaishno Devi University, Katra, Jammu &\nKashmir',value='Shri Mata Vaishno Devi University,Katra,Jammu & Kashmir',inplace=True)
df['Institute'].replace(to_replace='HNB Garhwal University Srinagar (Garhwal)',value='HNB Garhwal University Srinagar Garhwal',inplace=True)
df['Institute'].replace(to_replace='International Institute of Information Technology,\nNaya Raipur',value='IIIT Naya Raipur',inplace=True)
df['Institute'].replace(to_replace='International Institute of Information Technology,\nBhubaneswar',value='IIIT Bhubaneswar',inplace=True)
df['Institute'].replace(to_replace='National Institute of Food Technology\nEntrepreneurship and Management, Sonepat, Haryana',value='National Institute of Food Technology Entrepreneurship and Management,Sonepat,Haryana',inplace=True)
df['Institute'].replace(to_replace='National Institute of Food Technology Entrepreneurship and Management, Sonepat,\nHaryana',value='National Institute of Food Technology Entrepreneurship and Management,Sonepat,Haryana',inplace=True)

# %%
df['Institute'].replace(to_replace='Dr. B R Ambedkar National Institute of Technology,\nJalandhar',value='NITMJalandhar',inplace=True)
df['Institute'].replace(to_replace='Motilal Nehru National Institute of Technology\nAllahabad',value='NIT Allahabad',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology Karnataka, Surathkal',value='NIT Surathkal',inplace=True)
df['Institute'].replace(to_replace='Sardar Vallabhbhai National Institute of Technology,\nSurat',value='NIT Surat',inplace=True)
df['Institute'].replace(to_replace='Birla Institute of Technology, Mesra,  Ranchi',value='BITS Mesra',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Engineering Science and\nTechnology, Shibpur',value='Indian Institute of Engineering Science and Technology, Shibpur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT) Kalyani,\nWest Bengal',value='IIIT Kalyani',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT) Kilohrad,\nSonepat, Haryana',value='IIIT Sonepat',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT), Sri City,\nChittoor',value='IIIT Sri City',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT), Vadodara,\nGujrat',value='IIIT Vadodara',inplace=True)
df['Institute'].replace(to_replace='Pt. Dwarka Prasad Mishra Indian Institute of Information Technology, Design & Manufacture Jabalpur',value='IIIT-DM Jabalpur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT) Dharwad',value='IIIT Dharwad',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT) Kottayam',value='IIIT Kottayam',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT) Nagpur',value='IIIT Nagpur',inplace=True)
df['Institute'].replace(to_replace='J.K. Institute of Applied Physics & Technology, Department of Electronics & Communication, University of Allahabad-\nAllahabad',value='J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication, University of Allahabad',inplace=True)
df['Institute'].replace(to_replace='J.K. Institute of Applied Physics & Technology, Department\nof Electronics & Communication, University of Allahabad- Allahabad',value='J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication, University of Allahabad',inplace=True)
df['Institute'].replace(to_replace='National Institute of Foundry & Forge Technology, Hatia,\nRanchi',value='National Institute of Foundry & Forge Technology,Hatia,Ranchi',inplace=True)
df['Institute'].replace(to_replace='School of Engineering, Tezpur University, Napaam, Tezpur',value='School of Engineering,Tezpur University,Napaam,Tezpur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Engineering Science and Technology,\nShibpur',value='Indian Institute of Engineering Science and Technology, Shibpur',inplace=True)
df['Institute'].replace(to_replace='International Institute of Information Technology, Naya\nRaipur',value='IIIT Naya Raipur',inplace=True)
df['Institute'].replace(to_replace='J.K. Institute of Applied Physics & Technology,\nDepartment of Electronics & Communication, University of Allahabad- Allahabad',value='J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication, University of Allahabad',inplace=True)
df['Institute'].replace(to_replace='J.K. Institute of Applied Physics & Technology, Department of Electronics & Communication,\nUniversity of Allahabad- Allahabad',value='J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication, University of Allahabad',inplace=True)
df['Institute'].replace(to_replace='Institute of Technology, Guru Ghasidas\nVishwavidyalaya (A Central University), Bilaspur, (C.G.)',value='Institute of Technology, Guru Ghasidas Vishwavidyalaya,Bilaspur,(C.G.)',inplace=True)
df['Institute'].replace(to_replace='Visvesvaraya National Institute of Technology,\nNagpur',value='NIT Nagpur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT)\nRanchi',value='IIIT Ranchi',inplace=True)
df['Institute'].replace(to_replace='Pt. Dwarka Prasad Mishra Indian Institute of\nInformation Technology, Design & Manufacture\nJabalpur',value='IIIT-DM Jabalpur',inplace=True)
df['Institute'].replace(to_replace='National Institute of Food Technology Entrepreneurship and Management, Sonepat, Haryana',value='National Institute of Food Technology Entrepreneurship and Management,Sonepat',inplace=True)
df['Institute'].replace(to_replace='Ghani Khan Choudhary Institute of Engineering and Technology, Malda, West Bengal',value='Ghani Khan Choudhary Institute of Engineering and Technology,Malda',inplace=True)
df['Institute'].replace(to_replace='Visvesvaraya National Institute of Technology, Nagpur',value='NIT Nagpur',inplace=True)
df['Institute'].replace(to_replace='Ghani Khan Choudhary Institute of Engineering and Technology, Malda, West Bengal',value='Ghani Khan Choudhary Institute of Engineering and Technology,Malda',inplace=True)
df['Institute'].replace(to_replace='Sardar Vallabhbhai National Institute of Technology, Surat',value='NIT Surat',inplace=True)
df['Institute'].replace(to_replace='Ghani Khan Choudhary Institute of Engineering and\nTechnology, Malda, West Bengal',value='Ghani Khan Choudhary Institute of Engineering and Technology,Malda',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT)Kota,\nRajasthan',value='IIIT Kota',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT)\nKalyani, West Bengal',value='IIIT Kalyani',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT)\nKilohrad, Sonepat, Haryana',value='IIIT Sonepat',inplace=True)
df['Institute'].replace(to_replace='Atal Bihari Vajpayee Indian Institute of Information Technology & Management Gwalior',value='IIIT-M Gwalior',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT)Kota,\r\nRajasthan',value='IIIT Kota',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology Guwahati',value='IIIT Guwahati',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT)\r\nKalyani, West Bengal',value='IIIT Kalyani',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT) Una,\r\nHimachal Pradesh',value='IIIT Una',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT)\r\nKilohrad, Sonepat, Haryana',value='IIIT Sonepat',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT), Sri\r\nCity, Chittoor',value='IIIT Sri City',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT),\r\nVadodara, Gujrat',value='IIIT Vadodara',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology, Design &\r\nManufacturing, Kancheepuram',value='IIIT-DM Kancheepuram',inplace=True)
df['Institute'].replace(to_replace='Pt. Dwarka Prasad Mishra Indian Institute of Information Technology, Design & Manufacture\r\nJabalpur',value='IIIT-DM Jabalpur',inplace=True)
df['Institute'].replace(to_replace='Atal Bihari Vajpayee Indian Institute of Information Technology & Management Gwalior',value='IIIT-M Gwalior',inplace=True)
df['Institute'].replace(to_replace='Pt. Dwarka Prasad Mishra Indian Institute of\r\nInformation Technology, Design & Manufacture Jabalpur',value='IIIT-DM Jabalpur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology Srirangam,\r\nTiruchirappalli',value='IIIT Tiruchirappalli',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology Lucknow',value='IIIT Lucknow',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT)\r\nDharwad',value='IIIT Dharwad',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT)\r\nKottayam',value='IIIT Kottayam',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT)\r\nNagpur',value='IIIT Nagpur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology Bhagalpur',value='IIIT Bhagalpur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology Bhopal',value='IIIT Bhopal',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology Surat',value='IIIT Surat',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology Bhopal',value='IIIT Bhopal',inplace=True)
df['Institute'].replace(to_replace='Indian institute of information technology, Raichur,\r\nKarnataka',value='IIIT Raichur',inplace=True)
df['Institute'].replace(to_replace='Institute of Infrastructure, Technology, Research and\r\nManagement-Ahmedabad',value='Institute of Infrastructure Technology Research and Management,Ahmedabad',inplace=True)
df['Institute'].replace(to_replace='National Institute of Foundry & Forge Technology,\r\nHatia, Ranchi',value='National Institute of Foundry & Forge Technology,Ranchi',inplace=True)
df['Institute'].replace(to_replace='Sant Longowal Institute of Engineering and\r\nTechnology',value='Sant Longowal Institute of Engineering and Technology',inplace=True)
df['Institute'].replace(to_replace='School of Engineering, Tezpur University, Napaam,\r\nTezpur',value='School of Engineering,Tezpur University,Tezpur',inplace=True)
df['Institute'].replace(to_replace='Shri Mata Vaishno Devi University, Katra, Jammu &\r\nKashmir',value='Shri Mata Vaishno Devi University,Jammu & Kashmir',inplace=True)
df['Institute'].replace(to_replace='International Institute of Information Technology,\r\nNaya Raipur',value='IIIT Naya Raipur',inplace=True)
df['Institute'].replace(to_replace='International Institute of Information Technology,\r\nBhubaneswar',value='IIIT Bhubaneswar',inplace=True)
df['Institute'].replace(to_replace='National Institute of Food Technology\r\nEntrepreneurship and Management, Sonepat, Haryana',value='National Institute of Food Technology Entrepreneurship and Management,Sonepat',inplace=True)
df['Institute'].replace(to_replace='National Institute of Food Technology Entrepreneurship and Management, Sonepat,\r\nHaryana',value='National Institute of Food Technology Entrepreneurship and Management,Sonepat',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology, Warangal',value='NIT Warangal',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology Goa',value='NIT Goa',inplace=True)
df['Institute'].replace(to_replace='Dr. B R Ambedkar National Institute of Technology,\r\nJalandhar',value='NIT Jalandhar',inplace=True)
df['Institute'].replace(to_replace='Malaviya National Institute of Technology Jaipur',value='NIT Jaipur',inplace=True)
df['Institute'].replace(to_replace='Maulana Azad National Institute of Technology Bhopal',value='NIT Bhopal',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology  Agartala',value='NIT Agartala',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology Calicut',value='NIT Calicut',inplace=True)
df['Institute'].replace(to_replace='Motilal Nehru National Institute of Technology\r\nAllahabad',value='NIT Allahabad',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology Delhi',value='NIT Delhi',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology Durgapur',value='NIT Durgapur',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology Hamirpur',value='NIT Hamirpur',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology Meghalaya',value='NIT Meghalaya',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology Nagaland',value='NIT Nagaland',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology Patna',value='NIT Patna',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology Puducherry',value='NIT Puducherry',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology Raipur',value='NIT Raipur',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology Sikkim',value='NIT Sikkim',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology Arunachal Pradesh',value='NIT Arunachal Pradesh',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology, Jamshedpur',value='NIT Jameshdpur',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology, Kurukshetra',value='NIT Kurukshetra',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology, Manipur',value='NIT Manipur',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology, Mizoram',value='NIT Mizoram',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology, Rourkela',value='NIT Rourkela',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology, Silchar',value='NIT Silchar',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology, Srinagar',value='NIT Srinagar',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology, Tiruchirappalli',value='NIT Tiruchirappalli',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology, Uttarakhand',value='NIT Uttrakhand',inplace=True)
df['Institute'].replace(to_replace='Sardar Vallabhbhai National Institute of Technology,\r\nSurat',value='NIT Surat',inplace=True)
df['Institute'].replace(to_replace='National Institute of Technology, Andhra Pradesh',value='NIT Andhra Pradesh',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Engineering Science and\r\nTechnology, Shibpur',value='Indian Institute of Engineering Science and Technology,Shibpur',inplace=True)
df['Institute'].replace(to_replace='Motilal Nehru National Institute of Technology Allahabad',value='NIT Allahabad',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT) Kalyani,\r\nWest Bengal',value='IIIT Kalyani',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT) Kilohrad,\r\nSonepat, Haryana',value='IIIT Sonepat',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT), Sri City,\r\nChittoor',value='IIIT Sri City',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology(IIIT), Vadodara,\r\nGujrat',value='IIIT Vadodara',inplace=True)
df['Institute'].replace(to_replace='J.K. Institute of Applied Physics & Technology, Department of Electronics & Communication, University of Allahabad-\r\nAllahabad',value='J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication,University of Allahabad',inplace=True)
df['Institute'].replace(to_replace='J.K. Institute of Applied Physics & Technology, Department\r\nof Electronics & Communication, University of Allahabad- Allahabad',value='J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication,University of Allahabad',inplace=True)
df['Institute'].replace(to_replace='National Institute of Foundry & Forge Technology, Hatia,\r\nRanchi',value='National Institute of Foundry & Forge Technology,Ranchi',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Engineering Science and Technology,\r\nShibpur',value='Indian Institute of Engineering Science and Technology,Shibpur',inplace=True)
df['Institute'].replace(to_replace='International Institute of Information Technology, Naya\r\nRaipur',value='IIIT Naya Raipur',inplace=True)
df['Institute'].replace(to_replace='Ghani Khan Choudhary Institute of Engineering and\r\nTechnology, Malda, West Bengal',value='Ghani Khan Choudhary Institute of Engineering and Technology,West Bengal',inplace=True)
df['Institute'].replace(to_replace='Pt. Dwarka Prasad Mishra Indian Institute of\r\nInformation Technology, Design & Manufacture\r\nJabalpur',value='IIIT-DM Jabalpur',inplace=True)
df['Institute'].replace(to_replace='Indian Institute of Information Technology (IIIT)\r\nRanchi',value='IIIT Ranchi',inplace=True)
df['Institute'].replace(to_replace='J.K. Institute of Applied Physics & Technology, Department of Electronics & Communication,\r\nUniversity of Allahabad- Allahabad',value='J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication,University of Allahabad',inplace=True)
df['Institute'].replace(to_replace='Maulana Azad National Institute of Technology\r\nBhopal',value='NIT Bhopal',inplace=True)
df['Institute'].replace(to_replace='Visvesvaraya National Institute of Technology,\r\nNagpur',value='NIT Nagpur',inplace=True)
df['Institute'].replace(to_replace='Institute of Technology, Guru Ghasidas\r\nVishwavidyalaya (A Central University), Bilaspur, (C.G.)',value='Institute of Technology,Guru Ghasidas Vishwavidyalaya,Bilaspur,(C.G.)',inplace=True)
df['Institute'].replace(to_replace='J.K. Institute of Applied Physics & Technology,\r\nDepartment of Electronics & Communication, University of Allahabad- Allahabad',value='J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication,University of Allahabad',inplace=True)
df['Institute'].replace(to_replace='Ghani Khan Choudhary Institute of Engineering and Technology,Malda',value='Ghani Khan Choudhary Institute of Engineering and Technology,West Bengal',inplace=True)
df['Institute'].replace(to_replace='Institute of Technology, Guru Ghasidas Vishwavidyalaya,Bilaspur,(C.G.)',value='Institute of Technology,Guru Ghasidas Vishwavidyalaya,Bilaspur,(C.G.)',inplace=True)
df['Institute'].replace(to_replace='J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication, University of Allahabad',value='J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication,University of Allahabad',inplace=True)
df['Institute'].replace(to_replace='School of Engineering,Tezpur University,Napaam,Tezpur',value='School of Engineering,Tezpur University,Tezpur',inplace=True)
df['Institute'].replace(to_replace='NIT Meghalya',value='NIT Meghalaya',inplace=True)

# %%
print(df['Institute'].unique())
len(df['Institute'].unique())
# Out:
# ['IIIT-M Gwalior' 'IIIT Kota' 'IIIT Guwahati' 'IIIT Kalyani'
#  'IIIT Sonepat' 'IIIT Una' 'IIIT Sri City' 'IIIT Vadodara'
#  'IIIT Allahabad' 'IIIT-DM Kancheepuram' 'IIIT-DM Jabalpur' 'IIIT Manipur'
#  'IIIT Tiruchirappalli' 'IIIT Lucknow' 'IIIT Dharwad' 'IIIT-DM Kurnool'
#  'IIIT Kottayam' 'IIIT Ranchi' 'IIIT Nagpur' 'IIIT Pune' 'IIIT Bhagalpur'
#  'IIIT Bhopal' 'IIIT Surat' 'IIIT Agartala' 'IIIT Raichur'
#  'Assam University, Silchar' 'Gurukula Kangri Vishwavidyalaya, Haridwar'
#  'Indian Institute of Carpet Technology,  Bhadohi'
#  'Institute of Infrastructure Technology Research and Management,Ahmedabad'
#  'Institute of Technology,Guru Ghasidas Vishwavidyalaya,Bilaspur,(C.G.)'
#  'J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication,University of Allahabad'
#  'National Institute of Electronics and Information Technology, Aurangabad,Maharashtra'
#  'National Institute of Foundry & Forge Technology,Ranchi'
# ...

# %%
state=[]

# %%
def set_value(row_number, assigned_value): 
    return assigned_value[row_number] 
state={'Assam University, Silchar' : 'Assam', 
       'NIT Tiruchirappalli' : 'Tamil Nadu', 
       'NIT Surat' : 'Gujarat',
       'IIIT-M Gwalior':'All India',
      'IIIT Kota':'All India',
       'IIIT Guwahati':'All India',
       'IIIT Kalyani':'All India',
       'IIIT Sonepat':'All India',
       'IIIT Una':'All India',
       'IIIT Sri City':'All India',
       'IIIT Vadodara':'All India',
       'IIIT Allahabad':'All India',
       'IIIT-DM Kancheepuram':'All India',
       'IIIT-DM Jabalpur':'All India',
       'IIIT Manipur':'All India',
       'IIIT Tiruchirappalli':'All India',
       'IIIT Lucknow':'All India',
       'IIIT Dharwad':'All India',
       'IIIT-DM Kurnool':'All India',
       'IIIT Kottayam':'All India',
       'IIIT Ranchi':'All India',
       'IIIT Nagpur':'All India',
       'IIIT Pune':'All India',
       'IIIT Bhagalpur':'All India',
       'IIIT Bhopal':'All India',
       'IIIT Surat':'All India',
       'IIIT Agartala':'All India',
       'IIIT Raichur':'All India',
       'Gurukula Kangri Vishwavidyalaya, Haridwar':'All India',
      'Institute of Technology,Guru Ghasidas Vishwavidyalaya,Bilaspur,(C.G.)':'All India',
       'J.K. Institute of Applied Physics & Technology,Department of Electronics & Communication,University of Allahabad':'All India',
      'Indian Institute of Carpet Technology,  Bhadohi':'All India',
       'National Institute of Electronics and Information Technology, Aurangabad,Maharashtra':'All India',
      'National Institute of Foundry & Forge Technology,Ranchi':'All India',
       'Sant Longowal Institute of Engineering and Technology':'All India',
       'Mizoram University, Aizawl':'All India',
       'School of Engineering,Tezpur University,Tezpur':'All India',
       'School of Planning & Architecture, Bhopal':'All India',
       'School of Planning & Architecture, New Delhi':'All India',
       'School of Planning & Architecture,Vijayawada':'All India',
       'Shri Mata Vaishno Devi University,Jammu & Kashmir':'All India',
       'HNB Garhwal University Srinagar Garhwal':'All India',
       'IIIT Naya Raipur':'All India',
       'University of Hyderabad':'All India',
       'Jawaharlal Nehru University, Delhi':'All India',
       'IIIT Bhubaneswar':'All India',
       'Central institute of Technology Kokrajar, Assam':'All India',
       'Pondicherry Engineering College, Puducherry':'All India',
       'Central University of Rajasthan, Rajasthan':'All India',
       'National Institute of Food Technology Entrepreneurship and Management,Sonepat':'All India',
      'NIT Warangal':'Andhra Pradesh',
       'NIT Goa':'Goa',
       'NIT Jalandhar':'Punjab',
       'NIT Jaipur':'Rajashtahn',
       'NIT Bhopal':'Madhya Pradesh',
       'NIT Allahabad':'Uttar Pradesh',
       'NIT Agartala':'Tripura',
       'NIT Calicut':'Kerela',
       'NIT Delhi':'Delhi',
       'NIT Durgapur':'West Bengal',
       'NIT Hamirpur':'Himachal Pradesh',
       'NIT Surathkal':'Karnataka',
       'NIT Meghalaya':'Meghalaya',
       'NIT Nagaland':'Nagaland',
       'NIT Patna':'Bihar',
       'NIT Puducherry':'Puducherry',
       'NIT Raipur':'Chattisgarh',
       'NIT Sikkim':'Sikkim',
       'NIT Arunachal Pradesh':'Arunachal Pradesh',
       'NIT Jamshedpur':'Jharkhand',
       'NIT Kurukshetra':'Haryana',
       'NIT Manipur':'Manipur',
       'NIT Mizoram':'Mizoram',
       'NIT Rourkela':'Odhisa',
       'NIT Silchar':'Assam',
       'NIT Srinagar':'Jammu and Kahmir',
       'NIT Tiruchirappalli':'Tamil Nadu',
       'NIT Uttrakhand':'Uttarakhand',
       'NIT Surat':'Gujarat',
       'NIT Nagpur':'Maharashtra',
       'NIT Andhra Pradesh':'Andhra Pradesh',
       'BITS Mesra':'Jharkhand',
       'Indian Institute of Engineering Science and Technology,Shibpur':'West Bengal',
       'Punjab Engineering College, Chandigarh':'Punjab',
       'Ghani Khan Choudhary Institute of Engineering and Technology,West Bengal':'West Bengal',
       'Institute of Infrastructure Technology Research and Management,Ahmedabad':'All India',
       'NIT Jameshdpur':'Jharkhand'
      } 
df['State'] = df['Institute'].apply(set_value, args =(state, ))
df.head(50)
# Out:
#          Institute                                        Branch Name Quota  \
# 0   IIIT-M Gwalior  Computer Science and Engineering(4 year, Bache...    AI
# 1   IIIT-M Gwalior  Computer Science and Engineering(4 year, Bache...    AI
# 2   IIIT-M Gwalior  Computer Science and Engineering(4 year, Bache...    AI
# 3   IIIT-M Gwalior  Computer Science and Engineering(4 year, Bache...    AI
# 4   IIIT-M Gwalior  Computer Science and Engineering(4 year, Bache...    AI
# 5   IIIT-M Gwalior  Computer Science and Engineering(4 year, Bache...    AI
# 6   IIIT-M Gwalior  Computer Science and Engineering(4 year, Bache...    AI
# 7   IIIT-M Gwalior  Computer Science and Engineering(4 year, Bache...    AI
# 8   IIIT-M Gwalior  Computer Science and Engineering(4 year, Bache...    AI
# 9   IIIT-M Gwalior  Computer Science and Engineering(4 year, Bache...    AI
# 10  IIIT-M Gwalior  Computer Science and Engineering(4 year, Bache...    AI
# ...

# %%
df['Branch Name'].unique()
# Out:
# array(['CS',
#        'Integrated B. Tech.(IT) and M. Tech (IT)(5 year, Integrated B. Tech. and M. Tech. /MBA, Engineering)',
#        'Integrated B. Tech.(IT) and MBA(5 year, Integrated B. Tech. and M. Tech. /MBA, Engineering)',
#        'ECE', 'IT',
#        'Information Technology-Business Informatics(4 year, Bachelor of Technology,\r\nEngineering)',
#        'ME',
#        'Smart Manufacturing(4 year, Bachelor of Technology, Engineering)',
#        'B. Tech. Mechanical Engineering and M. Tech. in Mechanical Engineering with specialization in Product Design(5 year, Bachelor and Master of Technology (Dual\r\nDegree), Engineering)',
#        'B. Tech. Mechanical Engineering and M. Tech. in Mechanical Engineering with\r\nspecialization in Product Design(5 year, Bachelor and Master of Technology (Dual Degree), Engineering)',
# ...

# %%
df['Branch Name'].replace(to_replace='Computer Science and Engineering(4 year, Bachelor of Technology, Engineering)',value='CS',inplace=True)
df['Branch Name'].replace(to_replace='Electronics and Communication Engineering(4 year, Bachelor of Technology,\r\nEngineering)',value='ECE',inplace=True)
df['Branch Name'].replace(to_replace='Information Technology(4 year, Bachelor of Technology, Engineering)',value='IT',inplace=True)
df['Branch Name'].replace(to_replace='Mechanical Engineering(4 year, Bachelor of Technology, Engineering)',value='ME',inplace=True)

# %%
df['Branch Name'].replace(to_replace='Electronics and Communication Engineering(4 year, Bachelor of Technology, Engineering)',value='ECE',inplace=True)
df['Branch Name'].replace(to_replace='Computer Science(4 year, Bachelor of Technology, Engineering)',value='CS',inplace=True)
df['Branch Name'].replace(to_replace='Electronics and Communication Engineering(4 year, Bachelor of Technology,\r\nEngineering)',value='ECE',inplace=True)
df['Branch Name'].replace(to_replace='Information Technology(4 year, Bachelor of Technology, Engineering)',value='IT',inplace=True)
df['Branch Name'].replace(to_replace='Mechanical Engineering(4 year, Bachelor of Technology, Engineering)',value='ME',inplace=True)
df['Branch Name'].replace(to_replace='Computer Science(4 year, Bachelor of Technology, Engineering)',value='CS',inplace=True)
df['Branch Name'].replace(to_replace='Computer Science and Engineering(4 year, Bachelor of Technology, Engineering)',value='CSE',inplace=True)

# %%
df.tail()
print(df.dtypes)
df['Closing Rank']=df['Closing Rank'].astype(int)
# Out:
# Institute        object
# Branch Name      object
# Quota            object
# Category         object
# Seat Pool        object
# Opening Rank    float64
# Closing Rank      int64
# Round No          int64
# State            object
# dtype: object

# %%
#df.to_csv(r'round1_cleaned.csv', index = False)

# %%
#RANK TO PERCENTILE

# %%
rvp=pd.read_csv('rankVperc.csv')
print(rvp.head())
rvp['RANK']=rvp['RANK'].astype(int)
rvp.dtypes
# Out:
#   CATEGORY  RANK  PERCENTILE
# 0  GENERAL    13     100.000
# 1  GENERAL    34      99.999
# 2  GENERAL    53      99.998
# 3  GENERAL    69      99.997
# 4  GENERAL    80      99.996
# CATEGORY       object
# RANK            int32
# PERCENTILE    float64
# dtype: object

# %%
rvp['CATEGORY'].replace(to_replace='OBC',value='OBC-NCL',inplace=True)
rvp['CATEGORY'].replace(to_replace='OBC-PWD',value='OBC-NCL-PwD',inplace=True)
rvp['CATEGORY'].replace(to_replace='GENERAL',value='GEN',inplace=True)
rvp['CATEGORY'].replace(to_replace='GENERAL-PWD',value='GEN-PwD',inplace=True)
rvp['CATEGORY'].replace(to_replace='SC-PWD',value='SC-PwD',inplace=True)
rvp['CATEGORY'].replace(to_replace='ST-PWD',value='ST-PwD',inplace=True)
rvp['CATEGORY'].unique()
# Out:
# array(['GEN', 'EWS', 'OBC-NCL', 'SC', 'ST', 'GEN-PwD', 'EWS-PWD',
#        'OBC-NCL-PwD', 'SC-PwD', 'ST-PwD'], dtype=object)

# %%
rvp.to_csv(r'rvp_cleaned.csv', index = False)
